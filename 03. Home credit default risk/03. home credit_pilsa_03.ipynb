# %% [markdown]
# 원본 커널 : https://www.kaggle.com/eliotbarr/stacking-test-sklearn-xgboost-catboost-lightgbm

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew

import xgboost as xgb
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression

from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# %%
NFOLDS = 3
SEED = 0
NROWS = None

path = 'C:\\Users\\user\\Downloads\\home-credit-default-risk\\'

data = pd.read_csv(path+'application_train.csv')
test = pd.read_csv(path+'application_test.csv')
prev = pd.read_csv(path+'previous_application.csv')

# %% [markdown]
# <br>
#
# ### 1.1 train 데이터 object 데이터 뽑기

# %%
# data type이 object
categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

# %%
data.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
categorical_feats[:5]
# Out:
# ['NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'NAME_TYPE_SUITE']

# %% [markdown]
# <br>
#
# ### 1.2 pd.factorize() - 범주형 숫자 인코딩

# %%
for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_]) # 
    # data[f_] 는 인코딩된 값, # indexer 는 범주
    test[f_] = indexer.get_indexer(test[f_])

# %%
indexer.get_indexer(test['EMERGENCYSTATE_MODE'])
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
gc.enable()

y_train = data['TARGET']
del data['TARGET']

# %% [markdown]
# <br>
#
# ### 2.1 prev 데이터 object 데이터 뽑기

# %%
prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]

# %%
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

# %%
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']

del avg_prev['SK_ID_PREV']

# %% [markdown]
# <br>
#
# ### 3. data merge

# %%
x_train = data.merge(right = avg_prev.reset_index(), how ='left', on='SK_ID_CURR')
x_test = test.merge(right = avg_prev.reset_index(), how ='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

# %%
ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

# %%
kf = KFold(n_splits=NFOLDS, shuffle = True, random_state = SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['random_state'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

# %%
class CatboostWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['random_seed'] =seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

# %%
class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params = None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

# %%
class XgbWrapper(object):
    def __init__(self, seed= 0, params =None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)
        
    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label = y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)
        
    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest, ))
    oof_test_skf = np.empty((NFOLDS, ntest))
    
    for i , (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]
        
        clf.train(x_tr, y_tr)
        
        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)
        
    oof_test[:] = oof_test_skf.mean(axis = 0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed = SEED, params = xgb_params)
et = SklearnWrapper(ExtraTreesClassifier, SEED, et_params)
rf = SklearnWrapper(RandomForestClassifier, SEED, rf_params)
cb = CatboostWrapper(CatBoostClassifier, SEED, catboost_params)
lg = LightGBMWrapper(LGBMClassifier, SEED, lightgbm_params)

# %%
xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 0:	total: 218ms	remaining: 43.5s
# 1:	total: 296ms	remaining: 29.3s
# 2:	total: 378ms	remaining: 24.8s
# 3:	total: 453ms	remaining: 22.2s
# 4:	total: 536ms	remaining: 20.9s
# 5:	total: 628ms	remaining: 20.3s
# 6:	total: 719ms	remaining: 19.8s
# 7:	total: 800ms	remaining: 19.2s
# 8:	total: 869ms	remaining: 18.4s
# 9:	total: 947ms	remaining: 18s
# 10:	total: 1.03s	remaining: 17.6s
# 11:	total: 1.12s	remaining: 17.5s
# 12:	total: 1.19s	remaining: 17.2s
# 13:	total: 1.27s	remaining: 16.9s
# 14:	total: 1.39s	remaining: 17.2s
# 15:	total: 1.47s	remaining: 16.9s
# 16:	total: 1.55s	remaining: 16.6s
# 17:	total: 1.62s	remaining: 16.4s
# 18:	total: 1.71s	remaining: 16.2s
# 19:	total: 1.79s	remaining: 16.2s
# 20:	total: 1.95s	remaining: 16.6s
# 21:	total: 2.04s	remaining: 16.5s
# 22:	total: 2.12s	remaining: 16.3s
# 23:	total: 2.19s	remaining: 16.1s
# 24:	total: 2.27s	remaining: 15.9s
# 25:	total: 2.34s	remaining: 15.7s
# 26:	total: 2.51s	remaining: 16.1s
# 27:	total: 2.59s	remaining: 15.9s
# 28:	total: 2.66s	remaining: 15.7s
# 29:	total: 2.74s	remaining: 15.5s
# 30:	total: 2.82s	remaining: 15.4s
# 31:	total: 2.9s	remaining: 15.3s
# 32:	total: 2.98s	remaining: 15.1s
# 33:	total: 3.13s	remaining: 15.3s
# 34:	total: 3.22s	remaining: 15.2s
# 35:	total: 3.3s	remaining: 15s
# 36:	total: 3.38s	remaining: 14.9s
# 37:	total: 3.47s	remaining: 14.8s
# 38:	total: 3.55s	remaining: 14.6s
# 39:	total: 3.63s	remaining: 14.5s
# 40:	total: 3.78s	remaining: 14.7s
# 41:	total: 3.88s	remaining: 14.6s
# 42:	total: 3.96s	remaining: 14.4s
# 43:	total: 4.03s	remaining: 14.3s
# 44:	total: 4.1s	remaining: 14.1s
# 45:	total: 4.18s	remaining: 14s
# 46:	total: 4.26s	remaining: 13.9s
# 47:	total: 4.34s	remaining: 13.8s
# 48:	total: 4.44s	remaining: 13.7s
# 49:	total: 4.51s	remaining: 13.5s
# 50:	total: 4.6s	remaining: 13.4s
# 51:	total: 4.68s	remaining: 13.3s
# 52:	total: 4.76s	remaining: 13.2s
# 53:	total: 4.83s	remaining: 13.1s
# 54:	total: 4.91s	remaining: 12.9s
# 55:	total: 4.99s	remaining: 12.8s
# 56:	total: 5.06s	remaining: 12.7s
# 57:	total: 5.14s	remaining: 12.6s
# 58:	total: 5.22s	remaining: 12.5s
# 59:	total: 5.29s	remaining: 12.4s
# 60:	total: 5.37s	remaining: 12.2s
# 61:	total: 5.46s	remaining: 12.2s
# 62:	total: 5.54s	remaining: 12s
# 63:	total: 5.62s	remaining: 11.9s
# 64:	total: 5.7s	remaining: 11.8s
# 65:	total: 5.79s	remaining: 11.7s
# 66:	total: 5.86s	remaining: 11.6s
# 67:	total: 5.93s	remaining: 11.5s
# 68:	total: 6.02s	remaining: 11.4s
# 69:	total: 6.11s	remaining: 11.3s
# 70:	total: 6.23s	remaining: 11.3s
# 71:	total: 6.31s	remaining: 11.2s
# 72:	total: 6.38s	remaining: 11.1s
# 73:	total: 6.46s	remaining: 11s
# 74:	total: 6.54s	remaining: 10.9s
# 75:	total: 6.62s	remaining: 10.8s
# 76:	total: 6.7s	remaining: 10.7s
# 77:	total: 6.78s	remaining: 10.6s
# 78:	total: 6.86s	remaining: 10.5s
# 79:	total: 6.95s	remaining: 10.4s
# 80:	total: 7.03s	remaining: 10.3s
# 81:	total: 7.11s	remaining: 10.2s
# 82:	total: 7.19s	remaining: 10.1s
# 83:	total: 7.27s	remaining: 10s
# 84:	total: 7.35s	remaining: 9.94s
# 85:	total: 7.42s	remaining: 9.84s
# 86:	total: 7.5s	remaining: 9.75s
# 87:	total: 7.59s	remaining: 9.65s
# 88:	total: 7.67s	remaining: 9.57s
# 89:	total: 7.76s	remaining: 9.49s
# 90:	total: 7.85s	remaining: 9.4s
# 91:	total: 7.93s	remaining: 9.31s
# 92:	total: 8.01s	remaining: 9.22s
# 93:	total: 8.09s	remaining: 9.13s
# 94:	total: 8.17s	remaining: 9.03s
# 95:	total: 8.25s	remaining: 8.94s
# 96:	total: 8.33s	remaining: 8.85s
# 97:	total: 8.4s	remaining: 8.75s
# 98:	total: 8.49s	remaining: 8.66s
# 99:	total: 8.57s	remaining: 8.57s
# 100:	total: 8.65s	remaining: 8.48s
# 101:	total: 8.73s	remaining: 8.39s
# 102:	total: 8.81s	remaining: 8.3s
# 103:	total: 8.94s	remaining: 8.25s
# 104:	total: 9.02s	remaining: 8.16s
# 105:	total: 9.09s	remaining: 8.06s
# 106:	total: 9.17s	remaining: 7.97s
# 107:	total: 9.25s	remaining: 7.88s
# 108:	total: 9.33s	remaining: 7.79s
# 109:	total: 9.41s	remaining: 7.7s
# 110:	total: 9.49s	remaining: 7.61s
# 111:	total: 9.56s	remaining: 7.51s
# 112:	total: 9.65s	remaining: 7.43s
# 113:	total: 9.73s	remaining: 7.34s
# 114:	total: 9.81s	remaining: 7.25s
# 115:	total: 9.88s	remaining: 7.16s
# 116:	total: 9.97s	remaining: 7.07s
# 117:	total: 10.1s	remaining: 6.99s
# 118:	total: 10.1s	remaining: 6.9s
# 119:	total: 10.2s	remaining: 6.82s
# 120:	total: 10.3s	remaining: 6.73s
# 121:	total: 10.4s	remaining: 6.64s
# 122:	total: 10.5s	remaining: 6.56s
# 123:	total: 10.6s	remaining: 6.47s
# 124:	total: 10.7s	remaining: 6.41s
# 125:	total: 10.8s	remaining: 6.32s
# 126:	total: 10.8s	remaining: 6.23s
# 127:	total: 10.9s	remaining: 6.14s
# 128:	total: 11s	remaining: 6.04s
# 129:	total: 11.1s	remaining: 5.96s
# 130:	total: 11.1s	remaining: 5.87s
# 131:	total: 11.2s	remaining: 5.78s
# 132:	total: 11.3s	remaining: 5.69s
# 133:	total: 11.4s	remaining: 5.63s
# 134:	total: 11.5s	remaining: 5.54s
# 135:	total: 11.6s	remaining: 5.46s
# 136:	total: 11.7s	remaining: 5.37s
# 137:	total: 11.8s	remaining: 5.28s
# 138:	total: 11.8s	remaining: 5.2s
# 139:	total: 11.9s	remaining: 5.11s
# 140:	total: 12s	remaining: 5.02s
# 141:	total: 12.1s	remaining: 4.93s
# 142:	total: 12.1s	remaining: 4.84s
# 143:	total: 12.2s	remaining: 4.75s
# 144:	total: 12.3s	remaining: 4.67s
# 145:	total: 12.4s	remaining: 4.58s
# 146:	total: 12.5s	remaining: 4.5s
# 147:	total: 12.6s	remaining: 4.41s
# 148:	total: 12.6s	remaining: 4.33s
# 149:	total: 12.7s	remaining: 4.24s
# 150:	total: 12.8s	remaining: 4.16s
# 151:	total: 12.9s	remaining: 4.07s
# 152:	total: 13s	remaining: 3.98s
# 153:	total: 13.1s	remaining: 3.9s
# 154:	total: 13.1s	remaining: 3.82s
# 155:	total: 13.2s	remaining: 3.73s
# 156:	total: 13.3s	remaining: 3.64s
# 157:	total: 13.4s	remaining: 3.56s
# 158:	total: 13.5s	remaining: 3.47s
# 159:	total: 13.5s	remaining: 3.38s
# 160:	total: 13.6s	remaining: 3.3s
# 161:	total: 13.7s	remaining: 3.21s
# 162:	total: 13.8s	remaining: 3.13s
# 163:	total: 13.9s	remaining: 3.04s
# 164:	total: 13.9s	remaining: 2.96s
# 165:	total: 14s	remaining: 2.87s
# 166:	total: 14.1s	remaining: 2.79s
# 167:	total: 14.2s	remaining: 2.7s
# 168:	total: 14.3s	remaining: 2.62s
# 169:	total: 14.4s	remaining: 2.53s
# 170:	total: 14.4s	remaining: 2.45s
# 171:	total: 14.5s	remaining: 2.36s
# 172:	total: 14.6s	remaining: 2.28s
# 173:	total: 14.7s	remaining: 2.19s
# 174:	total: 14.8s	remaining: 2.11s
# 175:	total: 14.8s	remaining: 2.02s
# 176:	total: 14.9s	remaining: 1.94s
# 177:	total: 15s	remaining: 1.85s
# 178:	total: 15.1s	remaining: 1.77s
# 179:	total: 15.2s	remaining: 1.68s
# 180:	total: 15.2s	remaining: 1.6s
# 181:	total: 15.3s	remaining: 1.51s
# 182:	total: 15.4s	remaining: 1.43s
# 183:	total: 15.5s	remaining: 1.34s
# 184:	total: 15.5s	remaining: 1.26s
# 185:	total: 15.6s	remaining: 1.17s
# 186:	total: 15.7s	remaining: 1.09s
# 187:	total: 15.8s	remaining: 1.01s
# 188:	total: 15.9s	remaining: 923ms
# 189:	total: 15.9s	remaining: 838ms
# 190:	total: 16s	remaining: 754ms
# 191:	total: 16.1s	remaining: 670ms
# 192:	total: 16.1s	remaining: 586ms
# 193:	total: 16.2s	remaining: 502ms
# 194:	total: 16.3s	remaining: 419ms
# 195:	total: 16.4s	remaining: 335ms
# 196:	total: 16.5s	remaining: 251ms
# 197:	total: 16.6s	remaining: 167ms
# 198:	total: 16.7s	remaining: 83.7ms
# 199:	total: 16.7s	remaining: 0us
# 0:	total: 90.2ms	remaining: 18s
# 1:	total: 166ms	remaining: 16.5s
# 2:	total: 249ms	remaining: 16.4s
# 3:	total: 326ms	remaining: 16s
# 4:	total: 457ms	remaining: 17.8s
# 5:	total: 538ms	remaining: 17.4s
# 6:	total: 616ms	remaining: 17s
# 7:	total: 695ms	remaining: 16.7s
# 8:	total: 785ms	remaining: 16.7s
# 9:	total: 871ms	remaining: 16.5s
# 10:	total: 960ms	remaining: 16.5s
# 11:	total: 1.04s	remaining: 16.3s
# 12:	total: 1.12s	remaining: 16.1s
# 13:	total: 1.2s	remaining: 15.9s
# 14:	total: 1.29s	remaining: 15.9s
# 15:	total: 1.36s	remaining: 15.6s
# 16:	total: 1.44s	remaining: 15.5s
# 17:	total: 1.52s	remaining: 15.4s
# 18:	total: 1.59s	remaining: 15.1s
# 19:	total: 1.67s	remaining: 15s
# 20:	total: 1.75s	remaining: 14.9s
# 21:	total: 1.83s	remaining: 14.8s
# 22:	total: 1.91s	remaining: 14.7s
# 23:	total: 1.99s	remaining: 14.6s
# 24:	total: 2.08s	remaining: 14.6s
# 25:	total: 2.16s	remaining: 14.5s
# 26:	total: 2.26s	remaining: 14.5s
# 27:	total: 2.33s	remaining: 14.3s
# 28:	total: 2.39s	remaining: 14.1s
# 29:	total: 2.47s	remaining: 14s
# 30:	total: 2.56s	remaining: 13.9s
# 31:	total: 2.64s	remaining: 13.8s
# 32:	total: 2.73s	remaining: 13.8s
# 33:	total: 2.81s	remaining: 13.7s
# 34:	total: 2.96s	remaining: 14s
# 35:	total: 3.05s	remaining: 13.9s
# 36:	total: 3.13s	remaining: 13.8s
# 37:	total: 3.2s	remaining: 13.7s
# 38:	total: 3.29s	remaining: 13.6s
# 39:	total: 3.36s	remaining: 13.4s
# 40:	total: 3.44s	remaining: 13.3s
# 41:	total: 3.51s	remaining: 13.2s
# 42:	total: 3.59s	remaining: 13.1s
# 43:	total: 3.67s	remaining: 13s
# 44:	total: 3.74s	remaining: 12.9s
# 45:	total: 3.82s	remaining: 12.8s
# 46:	total: 3.92s	remaining: 12.7s
# 47:	total: 3.99s	remaining: 12.6s
# 48:	total: 4.07s	remaining: 12.5s
# 49:	total: 4.14s	remaining: 12.4s
# 50:	total: 4.22s	remaining: 12.3s
# 51:	total: 4.32s	remaining: 12.3s
# 52:	total: 4.42s	remaining: 12.3s
# 53:	total: 4.5s	remaining: 12.2s
# 54:	total: 4.57s	remaining: 12s
# 55:	total: 4.65s	remaining: 12s
# 56:	total: 4.73s	remaining: 11.9s
# 57:	total: 4.82s	remaining: 11.8s
# 58:	total: 4.9s	remaining: 11.7s
# 59:	total: 4.99s	remaining: 11.7s
# 60:	total: 5.08s	remaining: 11.6s
# 61:	total: 5.16s	remaining: 11.5s
# 62:	total: 5.24s	remaining: 11.4s
# 63:	total: 5.32s	remaining: 11.3s
# 64:	total: 5.39s	remaining: 11.2s
# 65:	total: 5.47s	remaining: 11.1s
# 66:	total: 5.55s	remaining: 11s
# 67:	total: 5.66s	remaining: 11s
# 68:	total: 5.74s	remaining: 10.9s
# 69:	total: 5.82s	remaining: 10.8s
# 70:	total: 5.9s	remaining: 10.7s
# 71:	total: 5.98s	remaining: 10.6s
# 72:	total: 6.07s	remaining: 10.6s
# 73:	total: 6.16s	remaining: 10.5s
# 74:	total: 6.23s	remaining: 10.4s
# 75:	total: 6.31s	remaining: 10.3s
# 76:	total: 6.38s	remaining: 10.2s
# 77:	total: 6.48s	remaining: 10.1s
# 78:	total: 6.56s	remaining: 10s
# 79:	total: 6.64s	remaining: 9.97s
# 80:	total: 6.73s	remaining: 9.89s
# 81:	total: 6.81s	remaining: 9.8s
# 82:	total: 6.89s	remaining: 9.71s
# 83:	total: 6.99s	remaining: 9.65s
# 84:	total: 7.07s	remaining: 9.57s
# 85:	total: 7.16s	remaining: 9.48s
# 86:	total: 7.23s	remaining: 9.39s
# 87:	total: 7.37s	remaining: 9.38s
# 88:	total: 7.45s	remaining: 9.29s
# 89:	total: 7.54s	remaining: 9.22s
# 90:	total: 7.62s	remaining: 9.13s
# 91:	total: 7.7s	remaining: 9.04s
# 92:	total: 7.79s	remaining: 8.96s
# 93:	total: 7.87s	remaining: 8.88s
# 94:	total: 7.95s	remaining: 8.78s
# 95:	total: 8.03s	remaining: 8.7s
# 96:	total: 8.11s	remaining: 8.62s
# 97:	total: 8.19s	remaining: 8.53s
# 98:	total: 8.27s	remaining: 8.44s
# 99:	total: 8.34s	remaining: 8.34s
# 100:	total: 8.42s	remaining: 8.25s
# 101:	total: 8.5s	remaining: 8.16s
# 102:	total: 8.58s	remaining: 8.08s
# 103:	total: 8.66s	remaining: 8s
# 104:	total: 8.73s	remaining: 7.9s
# 105:	total: 8.8s	remaining: 7.81s
# 106:	total: 8.89s	remaining: 7.73s
# 107:	total: 8.97s	remaining: 7.64s
# 108:	total: 9.05s	remaining: 7.56s
# 109:	total: 9.13s	remaining: 7.47s
# 110:	total: 9.21s	remaining: 7.38s
# 111:	total: 9.3s	remaining: 7.3s
# 112:	total: 9.38s	remaining: 7.22s
# 113:	total: 9.46s	remaining: 7.14s
# 114:	total: 9.54s	remaining: 7.05s
# 115:	total: 9.63s	remaining: 6.97s
# 116:	total: 9.7s	remaining: 6.88s
# 117:	total: 9.78s	remaining: 6.79s
# 118:	total: 9.86s	remaining: 6.71s
# 119:	total: 9.94s	remaining: 6.63s
# 120:	total: 10s	remaining: 6.54s
# 121:	total: 10.1s	remaining: 6.47s
# 122:	total: 10.2s	remaining: 6.38s
# 123:	total: 10.3s	remaining: 6.3s
# 124:	total: 10.4s	remaining: 6.22s
# 125:	total: 10.4s	remaining: 6.14s
# 126:	total: 10.5s	remaining: 6.05s
# 127:	total: 10.6s	remaining: 5.97s
# 128:	total: 10.7s	remaining: 5.89s
# 129:	total: 10.8s	remaining: 5.8s
# 130:	total: 10.9s	remaining: 5.72s
# 131:	total: 10.9s	remaining: 5.63s
# 132:	total: 11s	remaining: 5.55s
# 133:	total: 11.1s	remaining: 5.47s
# 134:	total: 11.2s	remaining: 5.38s
# 135:	total: 11.3s	remaining: 5.3s
# 136:	total: 11.3s	remaining: 5.22s
# 137:	total: 11.4s	remaining: 5.13s
# 138:	total: 11.5s	remaining: 5.05s
# 139:	total: 11.6s	remaining: 4.96s
# 140:	total: 11.7s	remaining: 4.88s
# 141:	total: 11.7s	remaining: 4.79s
# 142:	total: 11.8s	remaining: 4.71s
# 143:	total: 11.9s	remaining: 4.62s
# 144:	total: 11.9s	remaining: 4.53s
# 145:	total: 12s	remaining: 4.45s
# 146:	total: 12.1s	remaining: 4.36s
# 147:	total: 12.2s	remaining: 4.28s
# 148:	total: 12.3s	remaining: 4.2s
# 149:	total: 12.3s	remaining: 4.12s
# 150:	total: 12.4s	remaining: 4.03s
# 151:	total: 12.5s	remaining: 3.95s
# 152:	total: 12.6s	remaining: 3.87s
# 153:	total: 12.7s	remaining: 3.79s
# 154:	total: 12.7s	remaining: 3.7s
# 155:	total: 12.8s	remaining: 3.61s
# 156:	total: 12.9s	remaining: 3.53s
# 157:	total: 13s	remaining: 3.45s
# 158:	total: 13.1s	remaining: 3.37s
# 159:	total: 13.1s	remaining: 3.28s
# 160:	total: 13.2s	remaining: 3.2s
# 161:	total: 13.3s	remaining: 3.12s
# 162:	total: 13.4s	remaining: 3.04s
# 163:	total: 13.4s	remaining: 2.95s
# 164:	total: 13.5s	remaining: 2.87s
# 165:	total: 13.6s	remaining: 2.79s
# 166:	total: 13.7s	remaining: 2.7s
# 167:	total: 13.8s	remaining: 2.62s
# 168:	total: 13.9s	remaining: 2.54s
# 169:	total: 13.9s	remaining: 2.46s
# 170:	total: 14s	remaining: 2.38s
# 171:	total: 14.1s	remaining: 2.29s
# 172:	total: 14.2s	remaining: 2.21s
# 173:	total: 14.2s	remaining: 2.13s
# 174:	total: 14.3s	remaining: 2.04s
# 175:	total: 14.4s	remaining: 1.96s
# 176:	total: 14.5s	remaining: 1.88s
# 177:	total: 14.6s	remaining: 1.8s
# 178:	total: 14.6s	remaining: 1.72s
# 179:	total: 14.7s	remaining: 1.63s
# 180:	total: 14.8s	remaining: 1.55s
# 181:	total: 14.9s	remaining: 1.47s
# 182:	total: 14.9s	remaining: 1.39s
# 183:	total: 15s	remaining: 1.3s
# 184:	total: 15.1s	remaining: 1.22s
# 185:	total: 15.2s	remaining: 1.14s
# 186:	total: 15.2s	remaining: 1.06s
# 187:	total: 15.4s	remaining: 980ms
# 188:	total: 15.4s	remaining: 899ms
# 189:	total: 15.5s	remaining: 818ms
# 190:	total: 15.6s	remaining: 736ms
# 191:	total: 15.7s	remaining: 654ms
# 192:	total: 15.8s	remaining: 572ms
# 193:	total: 15.8s	remaining: 490ms
# 194:	total: 15.9s	remaining: 408ms
# 195:	total: 16s	remaining: 327ms
# 196:	total: 16.1s	remaining: 245ms
# 197:	total: 16.1s	remaining: 163ms
# 198:	total: 16.2s	remaining: 81.5ms
# 199:	total: 16.3s	remaining: 0us
# 0:	total: 88.1ms	remaining: 17.5s
# 1:	total: 165ms	remaining: 16.3s
# 2:	total: 243ms	remaining: 16s
# 3:	total: 321ms	remaining: 15.7s
# 4:	total: 400ms	remaining: 15.6s
# 5:	total: 478ms	remaining: 15.5s
# 6:	total: 560ms	remaining: 15.4s
# 7:	total: 643ms	remaining: 15.4s
# 8:	total: 716ms	remaining: 15.2s
# 9:	total: 802ms	remaining: 15.2s
# 10:	total: 881ms	remaining: 15.1s
# 11:	total: 972ms	remaining: 15.2s
# 12:	total: 1.04s	remaining: 15s
# 13:	total: 1.12s	remaining: 14.9s
# 14:	total: 1.2s	remaining: 14.7s
# 15:	total: 1.27s	remaining: 14.6s
# 16:	total: 1.35s	remaining: 14.6s
# 17:	total: 1.44s	remaining: 14.5s
# 18:	total: 1.51s	remaining: 14.4s
# 19:	total: 1.6s	remaining: 14.4s
# 20:	total: 1.68s	remaining: 14.3s
# 21:	total: 1.75s	remaining: 14.2s
# 22:	total: 1.83s	remaining: 14.1s
# 23:	total: 1.9s	remaining: 14s
# 24:	total: 1.98s	remaining: 13.8s
# 25:	total: 2.05s	remaining: 13.7s
# 26:	total: 2.12s	remaining: 13.6s
# 27:	total: 2.19s	remaining: 13.5s
# 28:	total: 2.27s	remaining: 13.4s
# 29:	total: 2.35s	remaining: 13.3s
# 30:	total: 2.43s	remaining: 13.3s
# 31:	total: 2.51s	remaining: 13.2s
# 32:	total: 2.59s	remaining: 13.1s
# 33:	total: 2.68s	remaining: 13.1s
# 34:	total: 2.75s	remaining: 13s
# 35:	total: 2.83s	remaining: 12.9s
# 36:	total: 2.91s	remaining: 12.8s
# 37:	total: 2.99s	remaining: 12.7s
# 38:	total: 3.05s	remaining: 12.6s
# 39:	total: 3.11s	remaining: 12.5s
# 40:	total: 3.18s	remaining: 12.3s
# 41:	total: 3.25s	remaining: 12.2s
# 42:	total: 3.32s	remaining: 12.1s
# 43:	total: 3.4s	remaining: 12s
# 44:	total: 3.47s	remaining: 11.9s
# 45:	total: 3.53s	remaining: 11.8s
# 46:	total: 3.6s	remaining: 11.7s
# 47:	total: 3.68s	remaining: 11.6s
# 48:	total: 3.74s	remaining: 11.5s
# 49:	total: 3.82s	remaining: 11.5s
# 50:	total: 3.91s	remaining: 11.4s
# 51:	total: 3.99s	remaining: 11.3s
# 52:	total: 4.06s	remaining: 11.3s
# 53:	total: 4.12s	remaining: 11.1s
# 54:	total: 4.21s	remaining: 11.1s
# 55:	total: 4.29s	remaining: 11s
# 56:	total: 4.35s	remaining: 10.9s
# 57:	total: 4.44s	remaining: 10.9s
# 58:	total: 4.51s	remaining: 10.8s
# 59:	total: 4.57s	remaining: 10.7s
# 60:	total: 4.66s	remaining: 10.6s
# 61:	total: 4.74s	remaining: 10.6s
# 62:	total: 4.83s	remaining: 10.5s
# 63:	total: 4.92s	remaining: 10.5s
# 64:	total: 5s	remaining: 10.4s
# 65:	total: 5.08s	remaining: 10.3s
# 66:	total: 5.17s	remaining: 10.3s
# 67:	total: 5.25s	remaining: 10.2s
# 68:	total: 5.33s	remaining: 10.1s
# 69:	total: 5.41s	remaining: 10s
# 70:	total: 5.5s	remaining: 9.99s
# 71:	total: 5.57s	remaining: 9.9s
# 72:	total: 5.65s	remaining: 9.84s
# 73:	total: 5.74s	remaining: 9.78s
# 74:	total: 5.82s	remaining: 9.7s
# 75:	total: 5.89s	remaining: 9.62s
# 76:	total: 5.97s	remaining: 9.54s
# 77:	total: 6.04s	remaining: 9.45s
# 78:	total: 6.12s	remaining: 9.38s
# 79:	total: 6.2s	remaining: 9.29s
# 80:	total: 6.27s	remaining: 9.21s
# 81:	total: 6.36s	remaining: 9.14s
# 82:	total: 6.44s	remaining: 9.08s
# 83:	total: 6.53s	remaining: 9.02s
# 84:	total: 6.59s	remaining: 8.92s
# 85:	total: 6.67s	remaining: 8.84s
# 86:	total: 6.75s	remaining: 8.76s
# 87:	total: 6.81s	remaining: 8.67s
# 88:	total: 6.87s	remaining: 8.57s
# 89:	total: 6.95s	remaining: 8.49s
# 90:	total: 7.03s	remaining: 8.42s
# 91:	total: 7.11s	remaining: 8.35s
# 92:	total: 7.2s	remaining: 8.28s
# 93:	total: 7.28s	remaining: 8.21s
# 94:	total: 7.36s	remaining: 8.13s
# 95:	total: 7.44s	remaining: 8.06s
# 96:	total: 7.52s	remaining: 7.99s
# 97:	total: 7.61s	remaining: 7.92s
# 98:	total: 7.7s	remaining: 7.85s
# 99:	total: 7.78s	remaining: 7.78s
# 100:	total: 7.84s	remaining: 7.69s
# 101:	total: 7.92s	remaining: 7.61s
# 102:	total: 8s	remaining: 7.54s
# 103:	total: 8.07s	remaining: 7.45s
# 104:	total: 8.15s	remaining: 7.38s
# 105:	total: 8.24s	remaining: 7.3s
# 106:	total: 8.32s	remaining: 7.23s
# 107:	total: 8.39s	remaining: 7.15s
# 108:	total: 8.47s	remaining: 7.07s
# 109:	total: 8.56s	remaining: 7s
# 110:	total: 8.63s	remaining: 6.92s
# 111:	total: 8.71s	remaining: 6.84s
# 112:	total: 8.79s	remaining: 6.77s
# 113:	total: 8.87s	remaining: 6.69s
# 114:	total: 8.95s	remaining: 6.61s
# 115:	total: 9.02s	remaining: 6.53s
# 116:	total: 9.09s	remaining: 6.45s
# 117:	total: 9.17s	remaining: 6.38s
# 118:	total: 9.26s	remaining: 6.3s
# 119:	total: 9.33s	remaining: 6.22s
# 120:	total: 9.41s	remaining: 6.14s
# 121:	total: 9.48s	remaining: 6.06s
# 122:	total: 9.56s	remaining: 5.99s
# 123:	total: 9.64s	remaining: 5.91s
# 124:	total: 9.72s	remaining: 5.83s
# 125:	total: 9.8s	remaining: 5.76s
# 126:	total: 9.88s	remaining: 5.68s
# 127:	total: 9.96s	remaining: 5.6s
# 128:	total: 10s	remaining: 5.52s
# 129:	total: 10.1s	remaining: 5.44s
# 130:	total: 10.2s	remaining: 5.36s
# 131:	total: 10.3s	remaining: 5.29s
# 132:	total: 10.3s	remaining: 5.21s
# 133:	total: 10.4s	remaining: 5.13s
# 134:	total: 10.5s	remaining: 5.05s
# 135:	total: 10.6s	remaining: 4.98s
# 136:	total: 10.7s	remaining: 4.9s
# 137:	total: 10.7s	remaining: 4.83s
# 138:	total: 10.8s	remaining: 4.75s
# 139:	total: 10.9s	remaining: 4.68s
# 140:	total: 11s	remaining: 4.6s
# 141:	total: 11.1s	remaining: 4.53s
# 142:	total: 11.1s	remaining: 4.44s
# 143:	total: 11.2s	remaining: 4.36s
# 144:	total: 11.3s	remaining: 4.3s
# 145:	total: 11.4s	remaining: 4.22s
# 146:	total: 11.5s	remaining: 4.14s
# 147:	total: 11.6s	remaining: 4.06s
# 148:	total: 11.6s	remaining: 3.98s
# 149:	total: 11.7s	remaining: 3.9s
# 150:	total: 11.8s	remaining: 3.83s
# 151:	total: 11.9s	remaining: 3.75s
# 152:	total: 12s	remaining: 3.67s
# 153:	total: 12.1s	remaining: 3.6s
# 154:	total: 12.1s	remaining: 3.52s
# 155:	total: 12.2s	remaining: 3.44s
# 156:	total: 12.3s	remaining: 3.37s
# 157:	total: 12.4s	remaining: 3.29s
# 158:	total: 12.5s	remaining: 3.21s
# 159:	total: 12.5s	remaining: 3.14s
# 160:	total: 12.6s	remaining: 3.06s
# 161:	total: 12.7s	remaining: 2.98s
# 162:	total: 12.8s	remaining: 2.9s
# 163:	total: 12.9s	remaining: 2.82s
# 164:	total: 12.9s	remaining: 2.74s
# 165:	total: 13s	remaining: 2.66s
# 166:	total: 13.1s	remaining: 2.59s
# 167:	total: 13.2s	remaining: 2.51s
# 168:	total: 13.3s	remaining: 2.43s
# 169:	total: 13.3s	remaining: 2.35s
# 170:	total: 13.4s	remaining: 2.27s
# 171:	total: 13.5s	remaining: 2.19s
# 172:	total: 13.6s	remaining: 2.12s
# 173:	total: 13.7s	remaining: 2.04s
# 174:	total: 13.7s	remaining: 1.96s
# 175:	total: 13.8s	remaining: 1.88s
# 176:	total: 13.9s	remaining: 1.8s
# 177:	total: 14s	remaining: 1.73s
# 178:	total: 14.1s	remaining: 1.65s
# 179:	total: 14.1s	remaining: 1.57s
# 180:	total: 14.2s	remaining: 1.49s
# 181:	total: 14.3s	remaining: 1.41s
# 182:	total: 14.3s	remaining: 1.33s
# 183:	total: 14.4s	remaining: 1.25s
# 184:	total: 14.5s	remaining: 1.17s
# 185:	total: 14.6s	remaining: 1.09s
# 186:	total: 14.6s	remaining: 1.02s
# 187:	total: 14.7s	remaining: 939ms
# 188:	total: 14.8s	remaining: 861ms
# 189:	total: 14.9s	remaining: 783ms
# 190:	total: 14.9s	remaining: 704ms
# 191:	total: 15s	remaining: 626ms
# 192:	total: 15.1s	remaining: 548ms
# 193:	total: 15.2s	remaining: 470ms
# 194:	total: 15.3s	remaining: 391ms
# 195:	total: 15.3s	remaining: 313ms
# 196:	total: 15.4s	remaining: 235ms
# 197:	total: 15.5s	remaining: 157ms
# 198:	total: 15.6s	remaining: 78.3ms
# 199:	total: 15.7s	remaining: 0us

# %%
print('XG-CV: {}'.format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print('ET-CV: {}'.format(sqrt(mean_squared_error(y_train, et_oof_train))))
print('RF-CV: {}'.format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print('CB-CV: {}'.format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.2594740573387384
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# CB-CV: 0.3308268881697429

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis = 1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis =1)

# %%
print('{}, {}'.format(x_train.shape, x_test.shape))
# Out:
# (307511, 4), (48744, 4)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]
test[['SK_ID_CURR', 'TARGET']].to_csv(path+'first_submission.csv', index = False, float_format ='%.8f' )
